# %%
# Mount google drive to import and export data
from google.colab import drive
import os

# Mount Google Drive
drive.mount('/content/drive')

# Create base project folder
base_path = "/content/drive/MyDrive/Crisis_Intelligence_System"
folders = [
    "data/raw", "data/processed", "notebooks", "models",
    "outputs/visualizations", "outputs/metrics", "outputs/decisions",
    "dashboard/components", "utils"
]

for folder in folders:
    os.makedirs(os.path.join(base_path, folder), exist_ok=True)

print("Folder structure created at:", base_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Folder structure created at: /content/drive/MyDrive/Crisis_Intelligence_System

# %%
# Import necessary libraries
import pandas as pd
import geopandas as gpd

# Store raw data path to import files
RAW_DATA_PATH = "/content/drive/My Drive/Crisis_Intelligence_System/data/raw/"

# Load CSV files
disaster_events = pd.read_csv(os.path.join(RAW_DATA_PATH, "disaster_events.csv"))
economic_activity = pd.read_csv(os.path.join(RAW_DATA_PATH, "economic_activity.csv"))
energy_consumption = pd.read_csv(os.path.join(RAW_DATA_PATH, "energy_consumption.csv"))
events_calendar = pd.read_csv(os.path.join(RAW_DATA_PATH, "events_calendar.csv"))
local_reviews = pd.read_csv(os.path.join(RAW_DATA_PATH, "local_business_reviews.csv"))
sensor_readings = pd.read_csv(os.path.join(RAW_DATA_PATH, "sensor_readings.csv"))
social_media = pd.read_csv(os.path.join(RAW_DATA_PATH, "social_media_stream.csv"))
transportation = pd.read_csv(os.path.join(RAW_DATA_PATH, "transportation.csv"))
weather_data = pd.read_csv(os.path.join(RAW_DATA_PATH, "weather_historical.csv"))

# Load GeoJSON file
city_map = gpd.read_file(os.path.join(RAW_DATA_PATH, "city_map.geojson"))

# %% [markdown]
# **Sensor Data**

# %% [markdown]
# Step 1: Preprocess Sensor Data

# %%
# Load and filter sensor data
sensor_readings['timestamp'] = pd.to_datetime(sensor_readings['timestamp'])

# Keep only active sensors
sensor_readings = sensor_readings[sensor_readings['status'] == 'active'].copy()

# Reset index for cleanliness
sensor_readings.reset_index(drop=True, inplace=True)

# Assign zones based on latitude and longitude

# Get min/max of lat and lon
lat_min, lat_max = sensor_readings['latitude'].min(), sensor_readings['latitude'].max()
lon_min, lon_max = sensor_readings['longitude'].min(), sensor_readings['longitude'].max()

# Compute mid-points to split into 2x2 grid
lat_mid = (lat_min + lat_max) / 2
lon_mid = (lon_min + lon_max) / 2

# Function to assign zone
def assign_zone(row):
    if row['latitude'] >= lat_mid and row['longitude'] <= lon_mid:
        return "Zone A"
    elif row['latitude'] >= lat_mid and row['longitude'] > lon_mid:
        return "Zone B"
    elif row['latitude'] < lat_mid and row['longitude'] <= lon_mid:
        return "Zone C"
    else:
        return "Zone D"

# Apply to DataFrame
sensor_readings['zone'] = sensor_readings.apply(assign_zone, axis=1)

# Classify disaster based on sensor type
def map_disaster(sensor_type):
    mapping = {
        'flood': 'flood',
        'temperature': 'fire',
        'seismic': 'earthquake',
        'humidity': 'hurricane',
    }
    return mapping.get(sensor_type, None)

sensor_readings['disaster'] = sensor_readings['sensor_type'].apply(map_disaster)

# Function to classify severity into levels
def classify_disaster_level(score):
    if score < 50:
        return "Level 0: No Disaster"
    elif score < 65:
        return "Level 1: Mild Disaster"
    elif score < 80:
        return "Level 2: Moderate Disaster"
    elif score < 90:
        return "Level 3: Severe Disaster"
    else:
        return "Level 4: Critical Disaster"

# Apply to your sensor dataframe
sensor_readings['severity'] = sensor_readings['reading_value'].apply(classify_disaster_level)

# Drop unwanted columns
sensor_readings.drop(columns=['sensor_id', 'sensor_type', 'reading_value', 'status'], inplace=True, errors='ignore')

# Replace disaster with None where severity is Level 0
sensor_readings.loc[sensor_readings['severity'] == 'Level 0: No Disaster', 'disaster'] = None

# Preview data frame
sensor_readings.head()
# Out:
#             timestamp   latitude   longitude    zone   disaster  \
# 0 2023-01-01 00:03:00  37.007146 -122.183781  Zone C       None
# 1 2023-01-01 00:05:00  37.507472 -121.568884  Zone B       None
# 2 2023-01-01 00:07:00  37.609489 -122.276630  Zone A       None
# 3 2023-01-01 00:08:00  37.243154 -122.339465  Zone C  hurricane
# 4 2023-01-01 00:15:00  37.963196 -122.376825  Zone A       None
#
#                  severity
# 0    Level 0: No Disaster
# 1    Level 0: No Disaster
# 2    Level 0: No Disaster
# 3  Level 1: Mild Disaster
# 4    Level 0: No Disaster

# %% [markdown]
# Step 2: Plot map of sensors

# %%
import pandas as pd
import folium

# Get min, max, and midpoints of lat/lon
lat_min, lat_max = sensor_readings['latitude'].min(), sensor_readings['latitude'].max()
lon_min, lon_max = sensor_readings['longitude'].min(), sensor_readings['longitude'].max()
lat_mid = (lat_min + lat_max) / 2
lon_mid = (lon_min + lon_max) / 2

# Define zone boundaries
zones = {
    "Zone A": [[lat_mid, lon_min], [lat_max, lon_mid]],
    "Zone B": [[lat_mid, lon_mid], [lat_max, lon_max]],
    "Zone C": [[lat_min, lon_min], [lat_mid, lon_mid]],
    "Zone D": [[lat_min, lon_mid], [lat_mid, lon_max]]
}

# Assign a color to each zone
zone_colors = {
    "Zone A": "red",
    "Zone B": "blue",
    "Zone C": "green",
    "Zone D": "purple"
}

# Create a folium map centered in the middle
map_center = [(lat_min + lat_max) / 2, (lon_min + lon_max) / 2]
m = folium.Map(location=map_center, zoom_start=11)

# Plot rectangles for each zone
for zone, ((lat1, lon1), (lat2, lon2)) in zones.items():
    bounds = [[lat1, lon1], [lat2, lon2]]
    folium.Rectangle(
        bounds=bounds,
        popup=zone,
        color=zone_colors[zone],
        fill=True,
        fill_color=zone_colors[zone],
        fill_opacity=0.3
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c77c8a824b0f76dce344f3501e8c446e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c77c8a824b0f76dce344f3501e8c446e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c77c8a824b0f76dce344f3501e8c446e = L.map(
#                 &quot;map_c77c8a824b0f76dce344f3501e8c446e&quot;,
#                 {
#                     center: [37.499973631068414, -121.99994571739366],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_892e614dcb58e1e2f6244389c429cd04 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_892e614dcb58e1e2f6244389c429cd04.addTo(map_c77c8a824b0f76dce344f3501e8c446e);
#
#
#             var rectangle_03caba7bc788766cc8440996cefde372 = L.rectangle(
#                 [[37.499973631068414, -122.49986046484024], [37.99994121728987, -121.99994571739366]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c77c8a824b0f76dce344f3501e8c446e);
#
#
#         var popup_1440d9ebd22444a54be6468cc21394a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea9e33a66c1f2fc313743a22d58059fe = $(`&lt;div id=&quot;html_ea9e33a66c1f2fc313743a22d58059fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Zone A&lt;/div&gt;`)[0];
#                 popup_1440d9ebd22444a54be6468cc21394a3.setContent(html_ea9e33a66c1f2fc313743a22d58059fe);
#
#
#
#         rectangle_03caba7bc788766cc8440996cefde372.bindPopup(popup_1440d9ebd22444a54be6468cc21394a3)
#         ;
#
#
#
#
#             var rectangle_f85229d5ab1340bdf1a92fb57659d77c = L.rectangle(
#                 [[37.499973631068414, -121.99994571739366], [37.99994121728987, -121.50003096994708]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c77c8a824b0f76dce344f3501e8c446e);
#
#
#         var popup_280758a5be32787e0b0d5bb0dcd953af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_46398e28cd3b3d943d517feb2f140002 = $(`&lt;div id=&quot;html_46398e28cd3b3d943d517feb2f140002&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Zone B&lt;/div&gt;`)[0];
#                 popup_280758a5be32787e0b0d5bb0dcd953af.setContent(html_46398e28cd3b3d943d517feb2f140002);
#
#
#
#         rectangle_f85229d5ab1340bdf1a92fb57659d77c.bindPopup(popup_280758a5be32787e0b0d5bb0dcd953af)
#         ;
#
#
#
#
#             var rectangle_8450a99048c0eab664ca95c136a36892 = L.rectangle(
#                 [[37.00000604484695, -122.49986046484024], [37.499973631068414, -121.99994571739366]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c77c8a824b0f76dce344f3501e8c446e);
#
#
#         var popup_eb1c747b712e1ab3663de74139455bfd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d794302eeb2aca30c5e89caf582c40f6 = $(`&lt;div id=&quot;html_d794302eeb2aca30c5e89caf582c40f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Zone C&lt;/div&gt;`)[0];
#                 popup_eb1c747b712e1ab3663de74139455bfd.setContent(html_d794302eeb2aca30c5e89caf582c40f6);
#
#
#
#         rectangle_8450a99048c0eab664ca95c136a36892.bindPopup(popup_eb1c747b712e1ab3663de74139455bfd)
#         ;
#
#
#
#
#             var rectangle_97cbab5289ad2130b7f718f0561

# %% [markdown]
# Step 2: Preprocess Social Media Data

# %%
social_media['timestamp'] = pd.to_datetime(social_media['timestamp'])

# Use keyword matching to label tweets (you can use NLP later)
def classify_tweet(text):
    text = text.lower()
    if 'flood' in text:
        return 'flood'
    elif 'fire' in text:
        return 'fire'
    elif 'earthquake' in text:
        return 'earthquake'
    elif 'cyclone' in text or 'storm' or 'hurricane' in text:
        return 'cyclone'
    return None

social_media['disaster'] = social_media['text'].apply(classify_tweet)
social_media = social_media.dropna(subset=['disaster'])

# %% [markdown]
# Plot map for insfrastructure location from city map

# %%
import geopandas as gpd
import folium

# Define colors for each infrastructure type
color_map = {
    'hospital': 'blue',
    'fire_station': 'red',
    'shelter': 'green'
}

# Center map based on data
map_center = [city_map.geometry.centroid.y.mean(), city_map.geometry.centroid.x.mean()]
m = folium.Map(location=map_center, zoom_start=12)

# Plot pins for each type
for infra_type in city_map['type'].unique():
    subset = city_map[city_map['type'] == infra_type]
    for _, row in subset.iterrows():
        lat = row.geometry.centroid.y
        lon = row.geometry.centroid.x
        folium.Marker(
            location=[lat, lon],
            popup=infra_type.title(),
            icon=folium.Icon(color=color_map.get(infra_type, 'gray'), icon='info-sign')
        ).add_to(m)

m
# Out:
# <ipython-input-42-da38b3299299>:12: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   map_center = [city_map.geometry.centroid.y.mean(), city_map.geometry.centroid.x.mean()]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f5dd76b9ccb0ce6c87a46b3c76e64e70 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f5dd76b9ccb0ce6c87a46b3c76e64e70&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f5dd76b9ccb0ce6c87a46b3c76e64e70 = L.map(
#                 &quot;map_f5dd76b9ccb0ce6c87a46b3c76e64e70&quot;,
#                 {
#                     center: [37.494294575876715, -121.9991115743134],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f44e6bb0b774f2fe204056afcd13a5cd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f44e6bb0b774f2fe204056afcd13a5cd.addTo(map_f5dd76b9ccb0ce6c87a46b3c76e64e70);
#
#
#             var marker_fef6553998f175221c0a1c99901fd888 = L.marker(
#                 [37.432842106328884, -122.49261530144322],
#                 {
# }
#             ).addTo(map_f5dd76b9ccb0ce6c87a46b3c76e64e70);
#
#
#             var icon_f8c4c299decb3a8dd7a1c549f3f352f5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c1d0589cd5411b5bd2ea5aed1223a114 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_539df358182e6e93322bfa69a662d708 = $(`&lt;div id=&quot;html_539df358182e6e93322bfa69a662d708&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_c1d0589cd5411b5bd2ea5aed1223a114.setContent(html_539df358182e6e93322bfa69a662d708);
#
#
#
#         marker_fef6553998f175221c0a1c99901fd888.bindPopup(popup_c1d0589cd5411b5bd2ea5aed1223a114)
#         ;
#
#
#
#
#                 marker_fef6553998f175221c0a1c99901fd888.setIcon(icon_f8c4c299decb3a8dd7a1c549f3f352f5);
#
#
#             var marker_1acb09b0be89f2d8af322d9ffe46ed50 = L.marker(
#                 [37.76062730813558, -121.53620557090734],
#                 {
# }
#             ).addTo(map_f5dd76b9ccb0ce6c87a46b3c76e64e70);
#
#
#             var icon_8c655efb7d284c44880054701cd7d3c9 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ff6afeb37240622bfe7dc701cdd7e754 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c915194a372f24934d97019e19849d97 = $(`&lt;div id=&quot;html_c915194a372f24934d97019e19849d97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_ff6afeb37240622bfe7dc701cdd7e754.setContent(html_c915194a372f24934d97019e19849d97);
#
#
#
#         marker_1acb09b0be89f2d8af322d9ffe46ed50.bindPopup(popup_ff6afeb37240622bfe7dc701cdd7e754)
#         ;
#
#
#
#
#                 marker_1acb09b0be89f2d8af322d9ffe46ed50.setIcon(icon_8c655efb7d284c44880054701cd7d3c9);
#
#
#             var marker_acdcc704a7211eec806b1915b451950c = L.marker(
#                 [37.770474544182875, -121.84106418208799],
#                 {
# }
#             ).addTo(map_f5dd76b9ccb0ce6c87a46b3c76e64e70);
#
#
#             var icon_b0e0cbe9f13f1be3b95eff324beede14 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_645e09e008276c2500ebf8f1fff6bc4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_303b05ebe54fdd388aabea63ccd6e1cc = $(`&lt;div id=&quot;html_303b05ebe54fdd388aabea63ccd6e1cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_645e09e008276c2500ebf8f1fff6bc4b.setContent(html_303b05ebe54fdd388aabea63ccd6e1cc);
#
#
#
#         marker_acdcc704a7211eec806b1915b451950c.bindPopup(popup_645e09e008276c2500ebf8f1fff6bc4b)
#         ;
#
#
#
#
#                 marker_acdcc704a7211eec806b1915b451950c.setIcon(icon_b0e0cbe9f13f1be3b95eff324beede14);
#
#
#             var marker_54ee60d25968e58e10da2c914cd430e3 = L.marker(
#                 [37.777302930754935, -122.1122063788773],
#                 {
# }
#             ).addTo(map_f5dd76b9ccb0ce6c87a46b3c76e64e70);

# %% [markdown]
# **Predict impact on infrastructure and recommmend action plan based on disaster**

# %%
import pandas as pd
import geopandas as gpd
from geopy.distance import geodesic

# Filter to the latest date only
latest_date = sensor_readings['timestamp'].dt.date.max()
sensor_filtered = sensor_readings[sensor_readings['timestamp'].dt.date == latest_date].copy()

# Drop rows with missing coordinates or severity
sensor_filtered = sensor_filtered.dropna(subset=['latitude', 'longitude', 'severity'])

# Rename geometry columns to avoid collision
city_map['infra_latitude'] = city_map.geometry.centroid.y
city_map['infra_longitude'] = city_map.geometry.centroid.x

# Rename for clarity
city_map = city_map.rename(columns={'type': 'infrastructure_type'})

# Cross join sensor readings and city map
sensor_filtered['key'] = 1
city_map['key'] = 1
cross_joined_df = pd.merge(sensor_filtered, city_map, on='key').drop('key', axis=1)

# Calculate geodesic distance
def calculate_distance(row):
    return geodesic(
        (row['latitude'], row['longitude']),
        (row['infra_latitude'], row['infra_longitude'])
    ).km

cross_joined_df['distance_km'] = cross_joined_df.apply(calculate_distance, axis=1)

# Predict impact level
def predict_impact(severity, distance_km):
    severity_level = int(severity.split(':')[0].split()[-1])  # e.g., "Level 3: Severe"

    if distance_km > 5:
        return 'Low'
    elif distance_km > 2:
        return 'Medium' if severity_level >= 2 else 'Low'
    else:
        if severity_level >= 4:
            return 'Critical'
        elif severity_level >= 3:
            return 'High'
        else:
            return 'Medium'

cross_joined_df['predicted_impact'] = cross_joined_df.apply(
    lambda row: predict_impact(row['severity'], row['distance_km']),
    axis=1
)

# Recommend action
def recommend_action(disaster, infra_type, impact, zone=None):
    if impact == "Critical":
        if infra_type == "shelter":
            return f"Evacuate {zone or 'this'} shelter immediately to alternate zone."
        elif infra_type == "hospital":
            return f"Reroute ambulances from hospital due to overload risk."
        elif infra_type == "fire_station":
            return f"Dispatch mobile units; station may be compromised."
    elif impact == "High":
        if infra_type == "hospital":
            return f"Scale up capacity or divert new cases from nearby areas."
        elif infra_type == "shelter":
            return f"Prepare secondary shelters and inform evacuees."
    elif impact == "Medium":
        return f"Monitor {infra_type} for escalation; notify emergency services."
    else:
        return f"No immediate action required."

cross_joined_df['recommended_action'] = cross_joined_df.apply(
    lambda row: recommend_action(row['disaster'], row['infrastructure_type'], row['predicted_impact'], row.get('zone')),
    axis=1
)

# Assign cross_joined_df to final_df
final_df = cross_joined_df  # This line is added

# Sort by timestamp
final_df = final_df.sort_values(by='timestamp').reset_index(drop=True)

# Drop geometry column as we have extracted latitude and longitude
final_df = final_df.drop(columns=['geometry'])

# Preview the result
final_df.head()
# Out:
# <ipython-input-14-5d58e97f4c85>:13: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   city_map['infra_latitude'] = city_map.geometry.centroid.y
# <ipython-input-14-5d58e97f4c85>:14: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   city_map['infra_longitude'] = city_map.geometry.centroid.x
#             timestamp  latitude   longitude    zone disaster  \
# 0 2023-02-04 00:01:00  37.86491 -121.593149  Zone B     None
# 1 2023-02-04 00:01:00  37.86491 -121.593149  Zone B     None
# 2 2023-02-04 00:01:00  37.86491 -121.593149  Zone B     None
# 3 2023-02-04 00:01:00  37.86491 -121.593149  Zone B     None
# 4 2023-02-04 00:01:00  37.86491 -121.593149  Zone B     None
#
#                severity          name infrastructure_type  infra_latitude  \
# 0  Level 0: No Disaster    Location 0            hospital       37.432842
# 1  Level 0: No Disaster  Location 658             shelter       37.871833
# 2  Level 0: No Disaster  Location 659        fire_station       37.671539
# 3  Level 0: No Disaster  Location 660            hospital       37.227079
# 4  Level 0: No Disaster  Location 661             shelter       37.530766
#
#    infra_longitude  distance_km predicted_impact  \
# 0      -122.492615    92.738142              Low
# 1      -122.187191    52.274854              Low
# 2      -122.364318    71.255238              Low
# 3      -121.670372    71.119761              Low
# 4      -122.330168    74.834801              Low
#
#               recommended_action
# 0  No immediate action required.
# 1  No immediate action required.
# 2  No immediate action required.
# 3  No immediate action required.
# 4  No immediate action required.

# %%
import geopandas as gpd
import folium

# Define colors for each infrastructure type
color_map = {
    'hospital': 'blue',
    'fire_station': 'red',
    'shelter': 'green'
}

# Filter final_df for flood-related disasters with Level 1+ impact
relevant_impacts = ['Medium', 'High', 'Critical']
flood_df = final_df[(final_df['disaster'] == 'flood') & (final_df['predicted_impact'].isin(relevant_impacts))]

# Create map centered on affected area
map_center = [flood_df['infra_latitude'].mean(), flood_df['infra_longitude'].mean()]
m = folium.Map(location=map_center, zoom_start=12)

# Plot markers for each affected infrastructure point
for _, row in flood_df.iterrows():
    infra_type = row['infrastructure_type']
    lat = row['infra_latitude']
    lon = row['infra_longitude']
    popup_text = f"{infra_type.title()}<br>Impact: {row['predicted_impact']}<br>Action: {row['recommended_action']}"

    folium.Marker(
        location=[lat, lon],
        popup=popup_text,
        icon=folium.Icon(color=color_map.get(infra_type, 'gray'), icon='info-sign')
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_448e041f43836bd3225f3b0a640417ec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_448e041f43836bd3225f3b0a640417ec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_448e041f43836bd3225f3b0a640417ec = L.map(
#                 &quot;map_448e041f43836bd3225f3b0a640417ec&quot;,
#                 {
#                     center: [37.53416319827449, -122.05429232802032],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7da85b91cc9742a081036c9ed7856caf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7da85b91cc9742a081036c9ed7856caf.addTo(map_448e041f43836bd3225f3b0a640417ec);
#
#
#             var marker_280f796123b01cdefccef76fd152d6d9 = L.marker(
#                 [37.97065720392766, -122.34916874558],
#                 {
# }
#             ).addTo(map_448e041f43836bd3225f3b0a640417ec);
#
#
#             var icon_56f2278cf60684b9683ba9f203a13867 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a0d383ee0b2f34d43be1c482ad120260 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1428a3c46be822461f6b88a88c993fb6 = $(`&lt;div id=&quot;html_1428a3c46be822461f6b88a88c993fb6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shelter&lt;br&gt;Impact: Medium&lt;br&gt;Action: Monitor shelter for escalation; notify emergency services.&lt;/div&gt;`)[0];
#                 popup_a0d383ee0b2f34d43be1c482ad120260.setContent(html_1428a3c46be822461f6b88a88c993fb6);
#
#
#
#         marker_280f796123b01cdefccef76fd152d6d9.bindPopup(popup_a0d383ee0b2f34d43be1c482ad120260)
#         ;
#
#
#
#
#                 marker_280f796123b01cdefccef76fd152d6d9.setIcon(icon_56f2278cf60684b9683ba9f203a13867);
#
#
#             var marker_1fba7668f4aebfde619a79f5cfc9f03a = L.marker(
#                 [37.98170528190333, -122.45055525199203],
#                 {
# }
#             ).addTo(map_448e041f43836bd3225f3b0a640417ec);
#
#
#             var icon_f5f2cb873f6885974d61f52d656452b5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_596e6ee60320bc63b3c2c446d871d5af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_44762e4b41807bd79189011779f8fc0b = $(`&lt;div id=&quot;html_44762e4b41807bd79189011779f8fc0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;br&gt;Impact: Medium&lt;br&gt;Action: Monitor hospital for escalation; notify emergency services.&lt;/div&gt;`)[0];
#                 popup_596e6ee60320bc63b3c2c446d871d5af.setContent(html_44762e4b41807bd79189011779f8fc0b);
#
#
#
#         marker_1fba7668f4aebfde619a79f5cfc9f03a.bindPopup(popup_596e6ee60320bc63b3c2c446d871d5af)
#         ;
#
#
#
#
#                 marker_1fba7668f4aebfde619a79f5cfc9f03a.setIcon(icon_f5f2cb873f6885974d61f52d656452b5);
#
#
#             var marker_962cc076668a6a11504acfa6f64c77bd = L.marker(
#                 [37.974680986252025, -122.41862240707351],
#                 {
# }
#             ).addTo(map_448e041f43836bd3225f3b0a640417ec);
#
#
#             var icon_2d482f313e475da54ad6255df9442004 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_cc84671987a1c6edbac6b23fc815514f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8bde1c54b8df792911aea0a9b0ba80a = $(`&lt;div id=&quot;html_a8bde1c54b8df792911aea0a9b0ba80a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;br&gt;Impact: Medium&lt;br&gt;Action: Monitor hospital for escalation; notify emergency services.&lt;/div&gt;`)[0];
#                 popup_cc84671987a1c6edbac6b23fc815514f.setContent(html_a8bde1c54b8df792911aea0a9b0ba80a);
#
#
#
#         marker_962cc076668a6a11504acfa6f64c77bd.bindPopup(popup_cc84671987a1c6edbac6b23fc815514f)
#         ;
#
#
#
#
#                 marker_962cc076668a6a11504ac

# %% [markdown]
# Save files in processed data for visualization

# %%
# Define the folder path
folder_path = "/content/drive/MyDrive/Crisis_Intelligence_System/data/processed/"

# Optional: Create the folder if it doesn't exist
import os
os.makedirs(folder_path, exist_ok=True)

# Save sensor_readings
sensor_filtered.to_csv(f"{folder_path}sensor_filtered.csv", index=False)

# Save final_df (impact + actions)
final_df.to_csv(f"{folder_path}final_df.csv", index=False)
